# %% [markdown]
# # Convolutional Neyral Network

# %%
import tensorflow
import numpy as np

# %%
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
cnn=Sequential()

# %%
cnn.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation="relu"))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(16,(3,3),activation="relu"))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Flatten())

# %%
cnn.add(Dense(1,activation="relu"))
cnn.add(Dense(1,activation="relu"))
cnn.add(Dense(1,activation="relu"))
cnn.add(Dense(1,activation="relu"))
cnn.add(Dense(1,activation="sigmoid"))

# %%
cnn.compile(loss="binary_crossentropy",optimizer="adam")

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        r"C:\Users\HP\Downloads\training_set",
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        r"C:\Users\HP\Downloads\test_set (1)",
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

cnn.fit(train_generator,steps_per_epoch=20,epochs=5,validation_data=validation_generator)
# Out:
# Found 8005 images belonging to 1 classes.
# Found 2023 images belonging to 1 classes.
# Epoch 1/5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - loss: 0.6884 - val_loss: 0.6832
# Epoch 2/5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 0.6785 - val_loss: 0.6734
# Epoch 3/5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - loss: 0.6688 - val_loss: 0.6637
# Epoch 4/5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 0.6592 - val_loss: 0.6542
# Epoch 5/5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - loss: 0.6497 - val_loss: 0.6448

# %%
from keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\HP\Downloads\test_set (1)\test\dogs\dog.4935.jpg",target_size=(64,64))

# %%
img=image.img_to_array(img)

# %%
img=np.expand_dims(img,axis=0)

# %%
p=cnn.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step

# %%
if p[0][0] < 0.5 :
    print("dog")
else :
    print("cat")
# Out:
# dog
